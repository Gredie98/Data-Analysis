# %%
import pandas as pd

# %% [markdown]
# ### 데이터 로드 및 확인

# %%
df = pd.read_csv('data-files\소방청_구조활동현황.csv', encoding='cp949')

print("="*50)
display(df.head())

print("="*50)
display(df.info())
# Out:
# ==================================================
#    번호       신고년월일   신고시각       출동년월일   출동시각   발생장소_시   발생장소_구 발생장소_동     사고원인  \
# 0   1  2023-01-01  00:00  2023-01-01  00:01      경기도      김포시    월곶면       화재
# 1   2  2023-01-01  00:00  2023-01-01  00:01      경기도      김포시    월곶면       화재
# 2   3  2023-01-01  00:01  2023-01-01  00:03     충청남도  천안시 동남구    신부동   잠금장치개방
# 3   4  2023-01-01  00:03  2023-01-01  00:04    서울특별시       중구  충무로2가       화재
# 4   5  2023-01-01  00:04  2023-01-01  00:05  제주특별자치도      제주시   이도이동  비화재보 확인
#
#   사고원인코드명_사고종별
# 0     자동차·철도차량
# 1     자동차·철도차량
# 2         출입문
# 3       건축·구조물
# 4     자동화재탐지설비
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651137 entries, 0 to 651136
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   번호            651137 non-null  int64
#  1   신고년월일         651137 non-null  object
#  2   신고시각          651137 non-null  object
#  3   출동년월일         651137 non-null  object
#  4   출동시각          651137 non-null  object
#  5   발생장소_시        651105 non-null  object
#  6   발생장소_구        651105 non-null  object
#  7   발생장소_동        647090 non-null  object
#  8   사고원인          651137 non-null  object
#  9   사고원인코드명_사고종별  651137 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 49.7+ MB
# None

# %% [markdown]
# ### 시계열 데이터 전처리

# %%
df['신고일시'] = df['신고년월일'] + " " + df['신고시각']
df['출동일시'] = df['출동년월일'] + " " + df['출동시각']
df['신고일시'] = pd.to_datetime(df['신고일시'])
df['출동일시'] = pd.to_datetime(df['출동일시'])

df.drop(['신고년월일'], axis=1, inplace=True)
df.drop(['신고시각'], axis=1, inplace=True)
df.drop(['출동년월일'], axis=1, inplace=True)
df.drop(['출동시각'], axis=1, inplace=True)

# %% [markdown]
# ### 상세 확인

# %%
# 컬럼별 결측치 확인
df.isnull().sum()
# Out:
# 번호                 0
# 발생장소_시            32
# 발생장소_구            32
# 발생장소_동          4047
# 사고원인               0
# 사고원인코드명_사고종별       0
# 신고일시               0
# 출동일시               0
# dtype: int64

# %%
# 특정 컬럼의 값 분포 확인
df['발생장소_구'].value_counts()
# Out:
# 발생장소_구
# 서구         12921
# 화성시        12415
# 평택시        11809
# 북구         10216
# 중구          9674
#            ...
# 울산광역시          3
# 광주광역시          2
# 전북특별자치도        2
# 대전광역시          1
# 제주특별자치도        1
# Name: count, Length: 242, dtype: int64

# %% [markdown]
# ### 데이터 그룹화

# %% [markdown]
# (1) `groupby` 활용

# %%
grouped_df = df.groupby(['발생장소_시', '발생장소_구'])['번호'].count().reset_index().rename(columns={'번호':'사고발생건수'})

grouped_df
# Out:
#       발생장소_시   발생장소_구  사고발생건수
# 0    강원특별자치도      강릉시    4897
# 1    강원특별자치도  강원특별자치도       8
# 2    강원특별자치도      고성군    1540
# 3    강원특별자치도      동해시    2144
# 4    강원특별자치도      삼척시    2525
# ..       ...      ...     ...
# 261     충청북도  청주시 서원구    1807
# 262     충청북도  청주시 청원구    2058
# 263     충청북도  청주시 흥덕구    2653
# 264     충청북도      충주시    2690
# 265     충청북도     충청북도       5
#
# [266 rows x 3 columns]

# %% [markdown]
# (2) `pivot_table` 활용

# %%
pivot_df = df.pivot_table(
    index=['발생장소_시', '발생장소_구']
    , aggfunc='size'
).reset_index(name='사고발생건수')

pivot_df
# Out:
#       발생장소_시   발생장소_구  사고발생건수
# 0    강원특별자치도      강릉시    4897
# 1    강원특별자치도  강원특별자치도       8
# 2    강원특별자치도      고성군    1540
# 3    강원특별자치도      동해시    2144
# 4    강원특별자치도      삼척시    2525
# ..       ...      ...     ...
# 261     충청북도  청주시 서원구    1807
# 262     충청북도  청주시 청원구    2058
# 263     충청북도  청주시 흥덕구    2653
# 264     충청북도      충주시    2690
# 265     충청북도     충청북도       5
#
# [266 rows x 3 columns]

# %% [markdown]
# ### 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# (1) `발생장소_시`별로 `사건발생건수` 시각화

# %%
plt.figure(figsize=(20, 5))
sns.barplot(
    data = pivot_df
    , x = '발생장소_시'
    , y = '사고발생건수'
    , hue = '발생장소_시'
)
# Out:
# <Axes: xlabel='발생장소_시', ylabel='사고발생건수'>

# %% [markdown]
# (2) 서울시의 `발생장소_구`별로 `사건발생건수` 시각화

# %%
# 서울시 데이터 추출 및 정리
seoul_pivot_df = pivot_df[pivot_df['발생장소_시']=='서울특별시'].reset_index(drop=True)

# '발생장소_구'가 서울특별시로 되어있는 경우를 제외
to_drop = seoul_pivot_df['발생장소_시'] == seoul_pivot_df['발생장소_구']
seoul_pivot_df = seoul_pivot_df[~to_drop].reset_index(drop=True)
seoul_pivot_df
# Out:
#    발생장소_시 발생장소_구  사고발생건수
# 0   서울특별시    강남구    8039
# 1   서울특별시    강동구    4059
# 2   서울특별시    강북구    4459
# 3   서울특별시    강서구    6132
# 4   서울특별시    관악구    4412
# 5   서울특별시    광진구    3291
# 6   서울특별시    구로구    3992
# 7   서울특별시    금천구    3490
# 8   서울특별시    노원구    4242
# 9   서울특별시    도봉구    3878
# 10  서울특별시   동대문구    3793
# 11  서울특별시    동작구    2990
# 12  서울특별시    마포구    6506
# 13  서울특별시   서대문구    4127
# 14  서울특별시    서초구    4824
# 15  서울특별시    성동구    2471
# 16  서울특별시    성북구    3551
# 17  서울특별시    송파구    6608
# 18  서울특별시    양천구    4045
# 19  서울특별시   영등포구    5795
# 20  서울특별시    용산구    3399
# 21  서울특별시    은평구    5490
# 22  서울특별시    종로구    2944
# 23  서울특별시     중구    1601
# 24  서울특별시    중랑구    3518

# %%
plt.figure(figsize=(20, 5))
sns.barplot(
    data = seoul_pivot_df
    , x = '발생장소_구'
    , y = '사고발생건수'
    , hue = '발생장소_구'
)
# Out:
# <Axes: xlabel='발생장소_구', ylabel='사고발생건수'>

# %% [markdown]
# ### 집계 데이터 생성

# %% [markdown]
# (1) 출동까지 걸린 시간 계산 (초)

# %%
df['출동소요시간'] = df['출동일시'] - df['신고일시']
df['출동소요시간_초'] = df['출동소요시간'].dt.total_seconds().astype(int)

# %%
df.head()
# Out:
#    번호   발생장소_시   발생장소_구 발생장소_동     사고원인 사고원인코드명_사고종별                신고일시  \
# 0   1      경기도      김포시    월곶면       화재     자동차·철도차량 2023-01-01 00:00:00
# 1   2      경기도      김포시    월곶면       화재     자동차·철도차량 2023-01-01 00:00:00
# 2   3     충청남도  천안시 동남구    신부동   잠금장치개방         출입문  2023-01-01 00:01:00
# 3   4    서울특별시       중구  충무로2가       화재       건축·구조물 2023-01-01 00:03:00
# 4   5  제주특별자치도      제주시   이도이동  비화재보 확인     자동화재탐지설비 2023-01-01 00:04:00
#
#                  출동일시          출동소요시간  출동소요시간_초
# 0 2023-01-01 00:01:00 0 days 00:01:00        60
# 1 2023-01-01 00:01:00 0 days 00:01:00        60
# 2 2023-01-01 00:03:00 0 days 00:02:00       120
# 3 2023-01-01 00:04:00 0 days 00:01:00        60
# 4 2023-01-01 00:05:00 0 days 00:01:00        60

# %% [markdown]
# ### 이상치 처리

# %% [markdown]
# (1) 출동일시가 신고일시보다 빠른 경우

# %%
# 출동소요시간에 음의 값이 있는 것을 확인
pd.set_option('display.float_format', '{:.2f}'.format)
df['출동소요시간_초'].describe()
# Out:
# count      651137.00
# mean            9.72
# std         94889.21
# min     -23326260.00
# 25%            60.00
# 50%            60.00
# 75%           120.00
# max      27563160.00
# Name: 출동소요시간_초, dtype: float64

# %%
# 출동일시가 신고일시보다 빠른 경우를 제거
to_drop = df['출동소요시간_초'] < 0
df = df[~to_drop]

# %% [markdown]
# (2) 이상치 시각화 (boxplot)

# %%
plt.figure(figsize=(20, 5))
sns.boxplot(
    data = df
    , x = '발생장소_시'
    , y = '출동소요시간_초'
    , hue = '발생장소_시'
)
# Out:
# <Axes: xlabel='발생장소_시', ylabel='출동소요시간_초'>

# %% [markdown]
# (3) 일반적인 값에서 크게 떨어진 이상치 처리

# %%
df['출동소요시간_초'].describe()
# Out:
# count     650365.00
# mean         514.05
# std        67151.07
# min            0.00
# 25%           60.00
# 50%           60.00
# 75%          120.00
# max     27563160.00
# Name: 출동소요시간_초, dtype: float64

# %% [markdown]
# a. IQR
# - IQR = Q3-Q1 = 120-60 = 60(초)
# - 하한 경계 = Q1-1.5×IQR = 60-1.5×60 = -30(초) ← 실질적으로 0초
# - 상한 경계 = Q3+1.5×IQR = 120+1.5×60 = 210(초)
#
# ⇒ 210초를 초과하는 값들을 이상치로 처리

# %%
df_IQR = df[df['출동소요시간_초'] <= 210]

plt.figure(figsize=(20, 5))
sns.boxplot(
    data = df_IQR
    , x = '발생장소_시'
    , y = '출동소요시간_초'
    , hue = '발생장소_시'
)
# Out:
# <Axes: xlabel='발생장소_시', ylabel='출동소요시간_초'>

# %% [markdown]
# b. Z-score
# <br/><br/>
# ⇒ 표준편차가 매우 크므로 알맞지 않음

# %% [markdown]
# c. 로그 변환 후 히스토그램<br/>
# : 시각적으로 컷오프 포인트 지정

# %%
import numpy as np

df_log = np.log1p(df['출동소요시간_초'])
df_log.plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# exp(7) ≈ 1,096초(약 18분)부터를 이상치로 간주
df_hist = df[df['출동소요시간_초'] <= 1100]

plt.figure(figsize=(20, 5))
sns.boxplot(
    data = df_hist
    , x = '발생장소_시'
    , y = '출동소요시간_초'
    , hue = '발생장소_시'
)
# Out:
# <Axes: xlabel='발생장소_시', ylabel='출동소요시간_초'>

# %% [markdown]
# ### 시별 평균 출동 시간

# %%
dispatch_by_location = df_hist.pivot_table(
    index = '발생장소_시'
    , values = '출동소요시간_초'
    , aggfunc = 'mean'
).reset_index().rename(columns={'출동소요시간_초':'평균출동시간_초'})

dispatch_by_location
# Out:
#      발생장소_시  평균출동시간_초
# 0   강원특별자치도     88.02
# 1       경기도     75.92
# 2      경상남도     84.17
# 3      경상북도     92.26
# 4     광주광역시     60.99
# 5     대구광역시     79.86
# 6     대전광역시    102.58
# 7     부산광역시     63.85
# 8     서울특별시     95.18
# 9   세종특별자치시     99.62
# 10    울산광역시     90.85
# 11    인천광역시     68.31
# 12     전라남도     79.42
# 13  전북특별자치도     69.34
# 14  제주특별자치도     90.06
# 15     충청남도     86.30
# 16     충청북도    103.35

# %%
mean_time = dispatch_by_location['평균출동시간_초'].mean()

plt.figure(figsize=(20, 5))
sns.barplot(
    data = dispatch_by_location
    , x = '발생장소_시'
    , y = '평균출동시간_초'
    , hue = '발생장소_시'
)

plt.axhline(
    mean_time
    , color = 'black'
    , linestyle = '--'
    , label = '평균 출동 소요 시간 (초)'
)

plt.legend()
plt.show()

# %% [markdown]
# ### 지도 시각화

# %%
import folium
from folium.plugins import MarkerCluster

# %%
df_station = pd.read_csv('data-files\서울시_서소위치(좌표계_WGS1984).csv', encoding='cp949')
df_station.head()
# Out:
#    순번   서소코드        서소이름    위도     경도
# 0   1  77250   종암119안전센터 37.60 127.03
# 1   2  77280    성북119구조대 37.60 127.03
# 2   3  75251  청량리119안전센터 37.59 127.05
# 3   4  81254   개화119안전센터 37.57 126.80
# 4   5  92280   서대문119구조대 37.57 126.93

# %%
centre = df_station.iloc[0]

map = folium.Map(
    location=[centre['위도'], centre['경도']]
    , zoom_start = 13
)

folium.Marker(
    location = [centre['위도'], centre['경도']]
    , popup = centre['서소이름']
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bc90ed434a887d83f16724d1a2809a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bc90ed434a887d83f16724d1a2809a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bc90ed434a887d83f16724d1a2809a7 = L.map(
#                 &quot;map_0bc90ed434a887d83f16724d1a2809a7&quot;,
#                 {
#                     center: [37.6024893, 127.0315631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_398c4131dedfeb03d05d4824d3f075c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_398c4131dedfeb03d05d4824d3f075c4.addTo(map_0bc90ed434a887d83f16724d1a2809a7);
#
#
#             var marker_908e41cae625052b9e72a68528b387f1 = L.marker(
#                 [37.6024893, 127.0315631],
#                 {}
#             ).addTo(map_0bc90ed434a887d83f16724d1a2809a7);
#
#
#         var popup_e7ced4f690a4925ddbeed6c238576e8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a01517d64c1de9caa3cec9585dfcc4af = $(`&lt;div id=&quot;html_a01517d64c1de9caa3cec9585dfcc4af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종암119안전센터&lt;/div&gt;`)[0];
#                 popup_e7ced4f690a4925ddbeed6c238576e8d.setContent(html_a01517d64c1de9caa3cec9585dfcc4af);
#
#
#
#         marker_908e41cae625052b9e72a68528b387f1.bindPopup(popup_e7ced4f690a4925ddbeed6c238576e8d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 반복문으로 모든 서소위치에 마크 추가
map = folium.Map(
    location=[centre['위도'], centre['경도']]
    , zoom_start = 13
)

for _, row in df_station.iterrows():
    folium.Marker(
        location = [row['위도'], row['경도']]
        , popup = row['서소이름']
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99ecec69be353d6ee90a652f296b84fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99ecec69be353d6ee90a652f296b84fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99ecec69be353d6ee90a652f296b84fd = L.map(
#                 &quot;map_99ecec69be353d6ee90a652f296b84fd&quot;,
#                 {
#                     center: [37.6024893, 127.0315631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1c50814650f6639f536c4641fb28a64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f1c50814650f6639f536c4641fb28a64.addTo(map_99ecec69be353d6ee90a652f296b84fd);
#
#
#             var marker_e4c0c4272f19904c21abdc2face8654c = L.marker(
#                 [37.6024893, 127.0315631],
#                 {}
#             ).addTo(map_99ecec69be353d6ee90a652f296b84fd);
#
#
#         var popup_d35672025d61cdd7082d2fa549bf4b7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a6612f4473bffc6e41e4a5435d947ec = $(`&lt;div id=&quot;html_4a6612f4473bffc6e41e4a5435d947ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종암119안전센터&lt;/div&gt;`)[0];
#                 popup_d35672025d61cdd7082d2fa549bf4b7f.setContent(html_4a6612f4473bffc6e41e4a5435d947ec);
#
#
#
#         marker_e4c0c4272f19904c21abdc2face8654c.bindPopup(popup_d35672025d61cdd7082d2fa549bf4b7f)
#         ;
#
#
#
#
#             var marker_f8595a49404b5f367b45c9fd2c55866a = L.marker(
#                 [37.6023076, 127.0317799],
#                 {}
#             ).addTo(map_99ecec69be353d6ee90a652f296b84fd);
#
#
#         var popup_e00708652c19cb255373cc4074a91b5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_add83e43a8325c61f5e1d5f970c6e90c = $(`&lt;div id=&quot;html_add83e43a8325c61f5e1d5f970c6e90c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;성북119구조대&lt;/div&gt;`)[0];
#                 popup_e00708652c19cb255373cc4074a91b5e.setContent(html_add83e43a8325c61f5e1d5f970c6e90c);
#
#
#
#         marker_f8595a49404b5f367b45c9fd2c55866a.bindPopup(popup_e00708652c19cb255373cc4074a91b5e)
#         ;
#
#
#
#
#             var marker_18943e16b4e4a984691a774d47f818bf = L.marker(
#                 [37.5871823, 127.0524],
#                 {}
#             ).addTo(map_99ecec69be353d6ee90a652f296b84fd);
#
#
#         var popup_021f4898c749c50eeb8ce34dd9dab95e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_470360b15d4c11e77c11f75aa1766621 = $(`&lt;div id=&quot;html_470360b15d4c11e77c11f75aa1766621&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;청량리119안전센터&lt;/div&gt;`)[0];
#                 popup_021f4898c749c50eeb8ce34dd9dab95e.setContent(html_470360b15d4c11e77c11f75aa1766621);
#
#
#
#         marker_18943e16b4e4a984691a774d47f818bf.bindPopup(popup_021f4898c749c50eeb8ce34dd9dab95e)
#         ;
#
#
#
#
#             var marker_6fb169fca4341457ae299f640b5ec820 = L.marker(
#                 [37.5749194, 126.803238],
#                 {}
#             ).addTo(map_99ecec69be353d6ee90a652f296b84fd);
#
#
#         var popup_86dde490c0b329668323b75800ea0764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f6cd1a89c01272fdfb0a291499b2b6b = $(`&lt;div id=&quot;html_1f6cd1a89c01272fdfb0a291499b2b6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;개화119안전센터&lt;/div&gt;`)[0];
#                 popup_86dde490c0b329668323b75800ea0764.setContent(html_1f6cd1a89c01272fdfb0a291499b2b6b);
#
#
#
#         marker_6fb169fca4341457ae299f640b5ec820.bindPopup(popup_86dde490c0b329668323b75800ea0764)
#         ;
#
#
#
#
#             var marker_c3b5b02ff9aedf160b72b536908ce542 = L.marker(
#                 [37.5718269, 126.9345704],
#                 {}
#             ).addTo(map_99ecec69be353d6ee90a652f296b84fd);
#
#
#         var popup_007998b661db935f8a464d9b5afa2bb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a635205fcbf0447dfeb696762d3d2d9 = $(`&lt;div id=&quot;html_4a635205fcbf0447dfeb696762d3d2d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서대문119구조대&lt;/div&gt;`)[0];
#                 popup_007998b661db935f8a464d9b5afa2bb8.setContent(html_4a635205fcbf0447dfeb696762d3d2d9);
#
#
#
#         marker_c3b5b02ff9aedf160b72b536908ce542.bindPopup(popup_007998b661db935f8a464d9b5afa2bb8)
#         ;
#
#
#
#
#             var marker_5122571e9ccf80ed2783ce978b26c947 = L.marker(
#                 [37.5733339, 126.9359802],
#                 {}
#             ).addTo(map_99ecec69be353d6ee90a652f296b84fd);

# %%
# 가독성 및 디자인 처리
map = folium.Map(
    location=[centre['위도'], centre['경도']]
    , zoom_start = 13
)

for _, row in df_station.iterrows():
    folium.Marker(
        location = [row['위도'], row['경도']]
        , icon = folium.Icon(color='red', icon='info-sign')
        , popup = folium.Popup(f"<h5>{row['서소이름']}</h5>", max_width=300)
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f14eee80e3f1354a06a57cd9e1925516 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f14eee80e3f1354a06a57cd9e1925516&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f14eee80e3f1354a06a57cd9e1925516 = L.map(
#                 &quot;map_f14eee80e3f1354a06a57cd9e1925516&quot;,
#                 {
#                     center: [37.6024893, 127.0315631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed99d22e9859f91b80243452d7908e3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ed99d22e9859f91b80243452d7908e3e.addTo(map_f14eee80e3f1354a06a57cd9e1925516);
#
#
#             var marker_a7dae0f03d34182d3ef35bfa404a96c7 = L.marker(
#                 [37.6024893, 127.0315631],
#                 {}
#             ).addTo(map_f14eee80e3f1354a06a57cd9e1925516);
#
#
#             var icon_7a9c55310c656760b4fedc18ffd794d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7dae0f03d34182d3ef35bfa404a96c7.setIcon(icon_7a9c55310c656760b4fedc18ffd794d6);
#
#
#         var popup_bc606d73f15ca22f1e94e7d6595b463c = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_0b1fefa8e5da9fcc1646180a5e817546 = $(`&lt;div id=&quot;html_0b1fefa8e5da9fcc1646180a5e817546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;종암119안전센터&lt;/h5&gt;&lt;/div&gt;`)[0];
#                 popup_bc606d73f15ca22f1e94e7d6595b463c.setContent(html_0b1fefa8e5da9fcc1646180a5e817546);
#
#
#
#         marker_a7dae0f03d34182d3ef35bfa404a96c7.bindPopup(popup_bc606d73f15ca22f1e94e7d6595b463c)
#         ;
#
#
#
#
#             var marker_796a3b3ab5d6711feaa15b7310c8612a = L.marker(
#                 [37.6023076, 127.0317799],
#                 {}
#             ).addTo(map_f14eee80e3f1354a06a57cd9e1925516);
#
#
#             var icon_024cefa52d4615f656537b3a535e9f16 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_796a3b3ab5d6711feaa15b7310c8612a.setIcon(icon_024cefa52d4615f656537b3a535e9f16);
#
#
#         var popup_6cf8bc48857b12cb12d949c9cb517925 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_ff7df5d83e176b74777629d10a152f6b = $(`&lt;div id=&quot;html_ff7df5d83e176b74777629d10a152f6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;성북119구조대&lt;/h5&gt;&lt;/div&gt;`)[0];
#                 popup_6cf8bc48857b12cb12d949c9cb517925.setContent(html_ff7df5d83e176b74777629d10a152f6b);
#
#
#
#         marker_796a3b3ab5d6711feaa15b7310c8612a.bindPopup(popup_6cf8bc48857b12cb12d949c9cb517925)
#         ;
#
#
#
#
#             var marker_749c212fc34514a3b687930186a5f503 = L.marker(
#                 [37.5871823, 127.0524],
#                 {}
#             ).addTo(map_f14eee80e3f1354a06a57cd9e1925516);
#
#
#             var icon_432f346ad2635cdde3ceb00b4bc39b82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_749c212fc34514a3b687930186a5f503.setIcon(icon_432f346ad2635cdde3ceb00b4bc39b82);
#
#
#         var popup_940f601ee1f9014168deb52313b229dd = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_e070f84ead6bbf4fdb2a02f853616228 = $(`&lt;div id=&quot;html_e070f84ead6bbf4fdb2a02f853616228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;청량리119안전센터&lt;/h5&gt;&lt;/div&gt;`)[0];
#                 popup_940f601ee1f9014168deb52313b229dd.setContent(html_e070f84ead6bbf4fdb2a02f853616228);
#
#
#
#         marker_749c212fc34514a3b687930186a5f503.bindPopup(popup_940f601ee1f9014168deb52313b229dd)
#         ;
#
#
#
#
#             var marker_ada12c14ae8553613a619703b8e76bc7 = L.marker(
#                 [37.5749194, 126.803238],
#                 {}
#             ).addTo(map_f14eee80e3f1354a06a57cd9e1925516);
#
#
#             var icon_861613e58dce42d2dbc532aaf421ca30 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &qu
